# %%
import torch
import torchvision.models as models

# Load the file
data = torch.load('resnet_bird_224x224_round14.pth', map_location=torch.device('cpu'))

# Check the type of the loaded object
print(type(data))
if isinstance(data, dict):
    print(data.keys())
# Out:
# <class 'collections.OrderedDict'>
# ...

# %%
import torch

checkpoint = torch.load("resnet_bird_224x224_roundWednesday.pth", map_location=torch.device('cpu'), weights_only=True)
print(type(checkpoint))  # Gibt aus, ob es ein dict (state_dict) oder ein Modell-Objekt ist
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 import torch
# ----> 3 checkpoint = torch.load("resnet_bird_224x224_roundWednesday.pth", map_location=torch.device('cpu'))
#       4 print(type(checkpoint))  # Gibt aus, ob es ein dict (state_dict) oder ein Modell-Objekt ist
#
# File ~/Documents/CAPSTONE PROJECT/app/env/lib/python3.11/site-packages/torch/serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)   1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
# ...

# %%
import graphviz
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Korrektur der Verbindungssyntax
dot = graphviz.Digraph(format='png')
dot.attr(rankdir='TB', size='8')

# Knoten für jede Schicht hinzufügen
dot.node('Input', 'Input\n(2048)')
dot.node('FC1', 'Linear\n(2048 → 512)')
dot.node('ReLU1', 'ReLU')
dot.node('FC2', 'Linear\n(512 → 150)')
dot.node('ReLU2', 'ReLU')
dot.node('FC3', 'Linear\n(150 → 10)')
dot.node('ReLU3', 'ReLU')
dot.node('Dropout', 'Dropout (p=0.3)')
dot.node('FC4', 'Linear\n(10 → 3)')
dot.node('Output', 'Output\n(3 Klassen)')

# Korrekte Verbindungen zwischen den Knoten erstellen
dot.edge('Input', 'FC1')
dot.edge('FC1', 'ReLU1')
dot.edge('ReLU1', 'FC2')
dot.edge('FC2', 'ReLU2')
dot.edge('ReLU2', 'FC3')
dot.edge('FC3', 'ReLU3')
dot.edge('ReLU3', 'Dropout')
dot.edge('Dropout', 'FC4')
dot.edge('FC4', 'Output')

# Speichern und Rendern
img_path = "fc_layer_structure"
dot.render(img_path)

# Rückgabe des Bildpfads für die Anzeige
img_path + ".png"
# Out:
# 'fc_layer_structure.png'

# %%
# Relatives Skalieren der Knotengrößen basierend auf der Anzahl der Neuronen
layer_sizes = {
    "Input": 2048,
    "FC1": 512,
    "ReLU1": 512,
    "FC2": 150,
    "ReLU2": 150,
    "FC3": 10,
    "ReLU3": 10,
    "Dropout": 10,
    "FC4": 3,
    "Output": 3
}

# Maximale Knotengröße für das größte Layer (Input Layer)
max_size = 2.0  # Maximale Skalierung
min_size = 0.5  # Minimale Skalierung

# Normierung der Größen für eine sinnvolle visuelle Darstellung
max_neurons = max(layer_sizes.values())
scaled_sizes = {layer: min_size + (size / max_neurons) * (max_size - min_size) for layer, size in layer_sizes.items()}

# Neues Graphviz Diagramm mit dynamischer Knotengröße
dot = graphviz.Digraph(format='png')
dot.attr(rankdir='TB', size='10')

# Knoten mit skalierter Schriftgröße hinzufügen
for layer, size in scaled_sizes.items():
    dot.node(layer, f"{layer}\n({layer_sizes[layer]})", width=str(size), height=str(size * 0.5))

# Verbindungen zwischen den Schichten
dot.edge('Input', 'FC1')
dot.edge('FC1', 'ReLU1')
dot.edge('ReLU1', 'FC2')
dot.edge('FC2', 'ReLU2')
dot.edge('ReLU2', 'FC3')
dot.edge('FC3', 'ReLU3')
dot.edge('ReLU3', 'Dropout')
dot.edge('Dropout', 'FC4')
dot.edge('FC4', 'Output')

# Speichern und Rendern des Diagramms
img_path_scaled = "fc_layer_structure_scaled"
dot.render(img_path_scaled)

# Rückgabe des Bildpfads für die Anzeige
img_path_scaled + ".png"
# Out:
# 'fc_layer_structure_scaled.png'
